# %% [markdown]
# 删除fdg中的无效信息  懒得删

# %%
import os
import json
dataDir = "../public/DifdgData/"
fileList = os.listdir(dataDir)
len(os.listdir(dataDir))
# Out:
# 47

# %%
with open(dataDir + fileList[0], 'r') as f:
    data = json.load(f)

# %%
# Out:
# {'0': {'nodes': [{'track_label_uuid': 'ego',
#     'label_class': 'VEHICLE',
#     'frame': 0,
#     'currentLane': '20001832',
#     'polygon': None,
#     'subDir': 'train2',
#     'width': None,
#     'length': None,
#     'height': None,
#     'cityX': 2989.9242190596,
#     'cityY': 1456.8206058897},
#    {'track_label_uuid': 'b54f4151-e692-4f42-8803-842e25e91495',
#     'label_class': 'VEHICLE',
#     'frame': 0,
#     'currentLane': '20001615',
#     'polygon': [[2991.0717096446, 1453.0050369213, 16.4670626965],
#      [2989.8627018704, 1454.2548585047, 16.4050448639],
#      [2994.3562383743, 1456.1806128515, 16.4329203962],
#      [2993.1472306001, 1457.4304344349, 16.3709025636]],
#     'subDir': 'train2',
#     'width': 1.74,
#     'length': 4.5687610094,
#     'height': 1.8,
#     'cityX': 2992.1094701224,
#     'cityY': 1455.2177356781},
#    {'track_label_uuid': 'f14cbbe5-81de-4c80-ba6c-3b6ba593cf34',
#     'label_class': 'VEHICLE',
#     'frame': 0,
# ...
